# %%
# !unzip /content/Midi.zip -d path_to_directory
# Out:
# Archive:  /content/Midi.zip
# replace path_to_directory/Midi/Aaron_Colin_Adams_-_Sonic_1-Mystery_Caves_Zone.mid? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: path_to_directory/Midi/Aaron_Colin_Adams_-_Sonic_1-Mystery_Caves_Zone.mid
#   inflating: path_to_directory/Midi/Animenz_-_This_game.mid
#   inflating: path_to_directory/Midi/Animenz_-_This_game_By_Animenz.mid
#   inflating: path_to_directory/Midi/Animenz_-_This_game_by_Animez_in_C_piano.mid
#   inflating: path_to_directory/Midi/Animenz_-_This_game_OP_Animenz_In_C.mid
#   inflating: path_to_directory/Midi/Animenz_-_This_Game_OP_Animenz_In_Eb.mid
#   inflating: path_to_directory/Midi/Animenz_-_This_game_op_by_Animenz_in_Eb_(Modify).mid
#   inflating: path_to_directory/Midi/Animez__-_This_Game_(In_E_flat_Advanced_Version)(re-modify).mid
#   inflating: path_to_directory/Midi/Arata_Iiyoshi_-_Primal_Dialga_Battle.mid
#   inflating: path_to_directory/Midi/Arrangement_-_Binding_of_Isaac_-_Ukulele_Arrangement.mid
#   inflating: path_to_directory/Midi/Asobimo_-_Iruna_-_Ganei_Battle_Theme.mid
#   inflating: path_to_directory/Midi/Ballroom_Dance_-_FF_VIII_-_Ballroom_Dance_-_FF_VIII.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_Banjo.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_BanjoB_Hill.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_File.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_mountain_.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_Mountain_Water_.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_Opening_.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_Clanker's_Cavern.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Conker's_bad_fur_day_big_poop.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Conker's_bad_fur_day_Windy_Hill.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Donkey_Kong_64_DK_Island.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Evening_Star_32x.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Parappa_The_Rapper._Level_2.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Sega_Mega_CD_BIOS (1).mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Sega_Mega_CD_BIOS.mid
#   inflating: path_to_directory/Midi/Benjy_shelton__-_Windows_Startup_.mid
#   inflating: path_to_directory/Midi/Ben_Ridge_-_Clepton.mid
#   inflating: path_to_directory/Midi/Cameron_Lee_Simpson_-_Mac_Dad_Z.mid
#   inflating: path_to_directory/Midi/dragon_quest_4_-_Level_Up.mid
#   inflating: path_to_directory/Midi/ENIX_-_Dragon_Warrior_3_(_Overworld_BGM_).mid
#   inflating: path_to_directory/Midi/ff_-_FFXII.mid
#   inflating: path_to_directory/Midi/Hing-Yan_Au_-_Song_3.mid
#   inflating: path_to_directory/Midi/Ichiro_Shimakura_-_Mario_Party_3_-_Good_Luck.mid
#   inflating: path_to_directory/Midi/inubro_-_no_more_words.mid
#   inflating: path_to_directory/Midi/Itowngameplay_-_bonnies_song.mid
#   inflating: path_to_directory/Midi/Junichi_Masuda_-_Pokemon_DPPt_-_Route_201_-_Piano_Arranged_In_3_4_Times.mid
#   inflating: path_to_directory/Midi/Junichi_Masuda_-_Pokemon_Fire_Red_-_Battle_Gym_Leader_-_Piano_Duet_-_Extended (1).mid
#   inflating: path_to_directory/Midi/Junichi_Masuda_-_Pokemon_Fire_Red_-_Battle_Gym_Leader_-_Piano_Duet_-_Extended.mid
#   inflating: path_to_directory/Midi/Junichi_Masuda_-_Pokemon_ORAS_-_Ending_-_Hard_Version.mid
#   inflating: path_to_directory/Midi/Konomi_Suzuki_(Edit_by_Viktor_Van_Den_Bergh)_-_This_Game_Easy_Version.mid
#   inflating: path_to_directory/Midi/Konomi_Suzuki_-_This_game_(In_E_flat_Hard_version)(re-Modify).mid
#   inflating: path_to_directory/Midi/Laura_Shigihara_-_Plants_Vs_Zombies_-_Watery_Grave_Piano.mid
#   inflating: path_to_directory/Midi/Lighthouse64_-_Green_Greens_(Kirby_Nightmare_in_Dreamland).mid
#   inflating: path_to_directory/Midi/mario474__-_deadlcked.mid
#   inflating: path_to_directory/Midi/mario474__-_figerdash_full_.mid
#   inflating: path_to_directory/Midi/mario474__-_mario_theme_rap.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_1_Rainbow_Route_Piano_Cover_Play_2_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_1_RainBow_Route_Piano_Cover_Play_50_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_7_Peppermint_Palace_Play_2_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_7_Peppermint_Palace_Play_50_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_9_Candy_Constellation_Play_2_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_9_Candy_Constellation_Play_50_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_Gourmet_Race_Round_1_and_3_(20Times).mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_Gourmet_Race_Round_1_and_3_(5_Times).mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_Gourmet_Race_Round_2_(20Times).mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_Gourmet_Race_Round_2_(5_Times).mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_Nightmare_In_Dreamland_Kirby_Air_Grind_Play_3_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Kirby_Nightmare_Kirby_Air_Grind_Piano_Cover.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Mii_Channel_Song.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pkmn-GSC-Route-1-Theme-Music-Box-2-Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pkmn-GSC-Route-1-Theme-Music-Box-50-Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Crystal_Gym_Play_3_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Fire_Red_Pallet_Town_Theme_(2_Times).mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Fire_Red_Pallet_Town_Theme_(50_Times).mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Fire_Red_Route_1_Piano_Cover_Hard_Version.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Fire_Red_Version_Gym_Theme_(Piano_Ver.).mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Fire_Red_Version_Route_1_(Piano_Ver.).mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Play_2_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Play_50_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Theme_Guitar_Cover_2_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Theme_Guitar_Cover_50_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Theme_Overdriven_Guitar_Cover_2_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Theme_Overdriven_Guitar_Cover_50_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Route_1_Theme_Advanced_Version.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Route_1_Theme_Advanced_Version_(Play_3_Times).mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Fure_Red_Route_1_Play_3_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_GSC_Goldenrod_City_Violin_Cover_Play_2_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_GSC_Goldenrod_City_Violin_Cover_Play_50_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_G_S_C_Bike_Ride_Theme_(3_Times).mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_G_S_C_Bike_Ride_Theme_(50_Times).mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_G_S_C_Goldenrod_City_Piano_Cover_50_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_G_S_C_Goldenrod_City_Piano_Cover_Play_2_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Liquid_Crystal_Gym_Piano_Cover.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Liquid_Crystal_Route_100_Theme_2_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Liquid_Crystal_Route_100_Theme_50_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Liquid_Crystal_Violet_City_Piano_Cover.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Liquid_Crystal_Violet_City_Play_3_Times.mid
#   inflating: path_to_directory/Midi/Nintendo_-_Pokemon_Poke_Center_(Piano_Ver.).mid
#   inflating: path_to_directory/Midi/Nobuo_Uematsu_-_Final_Fantasy_VII_Main_Theme.mid
#   inflating: path_to_directory/Midi/PCXP_-_Running_from_evil.mid
#   inflating: path_to_directory/Midi/Playstation_-_main_place.mid
#   inflating: path_to_directory/Midi/PS1_PARASITE_EVE_-_HISTORY_MUSEUM_PE.mid
#   inflating: path_to_directory/Midi/Sanchit_Sharma_-_Rhythm_Battle.mid
#   inflating: path_to_directory/Midi/Sonic_Advance_-_Angel_Island_Act_1.mid
#   inflating: path_to_directory/Midi/Sonic_Advance_-_Angel_Island_Act_1_(1).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_-_Angel_Island_Act_2.mid
#   inflating: path_to_directory/Midi/Sonic_Advance_-_Egg_Rocket_Act_1_(1).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_-_Egg_Rocket_Act_2_(Cosmic_Angel).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_-_Ice_Mountain_Act_1.mid
#   inflating: path_to_directory/Midi/Sonic_Advance_-_Neo_Green_Hill_Act_1.mid
#   inflating: path_to_directory/Midi/Sonic_Advance_-_Neo_Green_Hill_Zone_Act_1_-_ (1).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_-_Neo_Green_Hill_Zone_Act_1_-_ (2).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_-_Neo_Green_Hill_Zone_Act_1_-_ (3).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_-_Neo_Green_Hill_Zone_Act_1_-_.mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1.mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(1).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(2).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(3).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(4).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(5).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(6).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_2.mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Ice_Paradise_Act_1.mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Leaf_Forest_Act_1.mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Leaf_Forest_Act_1_(1).mid
#   inflating: path_to_directory/Midi/Sonic_Advance_2_-_Leaf_Forest_Act_2.mid
#   inflating: path_to_directory/Midi/Terranigma_-_Terranigma_-_Underworld.mid
#   inflating: path_to_directory/Midi/TheoAllen_-_Alkarian's_World.mid
#   inflating: path_to_directory/Midi/TheoAllen_-_Doomsday.mid
#   inflating: path_to_directory/Midi/The_Living_Tombstone_-_ (1).mid
#   inflating: path_to_directory/Midi/The_Living_Tombstone_-_.mid
#   inflating: path_to_directory/Midi/The_Living_Tombstone_-_fnaf_its__be_so_long (1).mid
#   inflating: path_to_directory/Midi/The_Living_Tombstone_-_fnaf_its__be_so_long.mid
#   inflating: path_to_directory/Midi/Toby_Fox_-_The_world_revolution.mid
#   inflating: path_to_directory/Midi/Toby_Fox_-_Undertale_-_Bergentruckung_and_Asgore_-_Piano_-_Hard_Version.mid
#   inflating: path_to_directory/Midi/Toby_Fox_-_Undertale_-_Waltzovania_-_Piano.mid
#   inflating: path_to_directory/Midi/Toby_Fox_-_Undertale_-_Waterfall_-_Piano_Arranged.mid
#   inflating: path_to_directory/Midi/Undertale_-_Bonetrousle.mid
#   inflating: path_to_directory/Midi/Undertale_-_Determination.mid
#   inflating: path_to_directory/Midi/Undertale_-_Megalovania (1).mid
#   inflating: path_to_directory/Midi/Undertale_-_Megalovania.mid
#   inflating: path_to_directory/Midi/Undertale_-_Sans.mid
#   inflating: path_to_directory/Midi/Undertale_-_Spear_Of_Justice.mid
#   inflating: path_to_directory/Midi/Unknown_-_.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Batman_Returns.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Bomberman_64.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_California_Games.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Castlevania_4.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Cool_Spot.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Crash_Bandicoot_Warped.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Desert_Strike.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Diddy_Kong.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Doom_64.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Dragon's_Fury.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Duke_Nukem (1).mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Duke_Nukem.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Eternal_Champions.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_F-Zero (1).mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_F-Zero.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_2.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_3.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_7 (1).mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_7.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_8 (1).mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_8.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Goldeneye_007.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Illusion_Of_Gaia (1).mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Illusion_Of_Gaia.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Killer_Instinct.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Mario_Kart_64.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Mario_Kart_64_Raceway.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Mario_Party.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_2.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_8.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_X.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_X2.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_X3.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_X4 (1).mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_X4.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_NHL_96.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Phantasy_Star_4.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Pokemon_Snap.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Power_Rangers.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Ridge_Racer (1).mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Ridge_Racer.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Secret_Of_Mana.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Sim_City.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Sim_City_2000 (1).mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Sim_City_2000.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Sonic_The_Hedgehog.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Star_Fox_64 (1).mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Star_Fox_64.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Street_Fighter_2.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Super_Mario_All_Stars.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Super_Mario_Kart.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Super_Mario_World.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Super_Mario_World_2__Yoshi's_Island.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Tekken_2 (1).mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Tekken_2.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Waverace.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Wing_Commander.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Xenogears (1).mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Xenogears.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Zelda_3__A_Link_To_The_Past.mid
#   inflating: path_to_directory/Midi/Video_Game_Themes_-_Zelda__Ocarina_Of_Time.mid
#   inflating: path_to_directory/Midi/Zengarang_-_The_Promise_Bios_Medley.mid
#   inflating: path_to_directory/Midi/ZUN_-_The_Rabbit_Has_Landed.mid
# Midi/ZUN_-_魔法決戦！～Fight_it_out!.mid:  mismatching "local" filename (Midi/ZUN_-_щнФц│Хц▒║цИжя╝Бя╜ЮFight_it_out!.mid),
#          continuing with "central" filename version
#   inflating: path_to_directory/Midi/ZUN_-_魔法決戦！～Fight_it_out!.mid

# %%
#courtesy of https://www.analyticsvidhya.com/blog/2020/01/how-to-perform-automatic-music-generation/
from music21 import *
import os
import numpy as np
from keras.layers import *
from keras.models import *
from keras.callbacks import *
import keras.backend as K
from keras.models import load_model
import random

# %%
def read_midi(file):
    
    print("Loading Music File:",file)
    
    notes=[]
    notes_to_parse = None
    
    #parsing a midi file
    midi = converter.parse(file)
  
    #grouping based on different instruments
    s2 = instrument.partitionByInstrument(midi)

    #Looping over all the instruments
    if s2 == None:
      pass
    else:
      try:
        for part in s2.parts:
        
            #select elements of only piano
            if 'Piano' in str(part): 
            
                notes_to_parse = part.recurse() 
          
                #finding whether a particular element is note or a chord
                for element in notes_to_parse:
                    
                    #note
                    if isinstance(element, note.Note):
                        notes.append(str(element.pitch))
                    
                    #chord
                    elif isinstance(element, chord.Chord):
                        notes.append('.'.join(str(n) for n in element.normalOrder))
      except:
          pass

    return np.array(notes)

# %%
#specify the path
path='/content/path_to_directory/Midi/'

#read all the filenames
files=[i for i in os.listdir(path) if i.endswith(".mid")]

#reading each midi file
notes_array = np.array([read_midi(path+i) for i in files])
# Out:
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Conker's_bad_fur_day_big_poop.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Mii_Channel_Song.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Fire_Red_Pallet_Town_Theme_(2_Times).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Street_Fighter_2.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Liquid_Crystal_Violet_City_Piano_Cover.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader.mid
# Loading Music File: /content/path_to_directory/Midi/Toby_Fox_-_The_world_revolution.mid
# Loading Music File: /content/path_to_directory/Midi/mario474__-_figerdash_full_.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_Banjo.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Ice_Paradise_Act_1.mid
# Loading Music File: /content/path_to_directory/Midi/Arrangement_-_Binding_of_Isaac_-_Ukulele_Arrangement.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_1_Rainbow_Route_Piano_Cover_Play_2_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_Mountain_Water_.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Eternal_Champions.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_7 (1).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_7.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1.mid
# Loading Music File: /content/path_to_directory/Midi/The_Living_Tombstone_-_.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Liquid_Crystal_Gym_Piano_Cover.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Fire_Red_Version_Route_1_(Piano_Ver.).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Waverace.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_2.mid
# Loading Music File: /content/path_to_directory/Midi/Undertale_-_Bonetrousle.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Sega_Mega_CD_BIOS (1).mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_-_Angel_Island_Act_1_(1).mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_-_Neo_Green_Hill_Act_1.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_Gourmet_Race_Round_2_(20Times).mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Play_50_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_Nightmare_Kirby_Air_Grind_Piano_Cover.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pkmn-GSC-Route-1-Theme-Music-Box-50-Times.mid
# Loading Music File: /content/path_to_directory/Midi/The_Living_Tombstone_-_ (1).mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_-_Egg_Rocket_Act_2_(Cosmic_Angel).mid
# Loading Music File: /content/path_to_directory/Midi/PCXP_-_Running_from_evil.mid
# Loading Music File: /content/path_to_directory/Midi/Sanchit_Sharma_-_Rhythm_Battle.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Star_Fox_64 (1).mid
# Loading Music File: /content/path_to_directory/Midi/Asobimo_-_Iruna_-_Ganei_Battle_Theme.mid
# Loading Music File: /content/path_to_directory/Midi/Ichiro_Shimakura_-_Mario_Party_3_-_Good_Luck.mid
# Loading Music File: /content/path_to_directory/Midi/Unknown_-_.mid
# Loading Music File: /content/path_to_directory/Midi/Konomi_Suzuki_(Edit_by_Viktor_Van_Den_Bergh)_-_This_Game_Easy_Version.mid
# Loading Music File: /content/path_to_directory/Midi/Ballroom_Dance_-_FF_VIII_-_Ballroom_Dance_-_FF_VIII.mid
# Loading Music File: /content/path_to_directory/Midi/mario474__-_deadlcked.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(6).mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Leaf_Forest_Act_1.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Mario_Party.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Play_2_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Leaf_Forest_Act_1_(1).mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Liquid_Crystal_Violet_City_Play_3_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Playstation_-_main_place.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_F-Zero (1).mid
# Loading Music File: /content/path_to_directory/Midi/inubro_-_no_more_words.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Mario_Kart_64_Raceway.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Phantasy_Star_4.mid
# Loading Music File: /content/path_to_directory/Midi/Animenz_-_This_game.mid
# Loading Music File: /content/path_to_directory/Midi/Junichi_Masuda_-_Pokemon_Fire_Red_-_Battle_Gym_Leader_-_Piano_Duet_-_Extended (1).mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Crystal_Gym_Play_3_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Super_Mario_All_Stars.mid
# Loading Music File: /content/path_to_directory/Midi/Hing-Yan_Au_-_Song_3.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Wing_Commander.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Theme_Guitar_Cover_50_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_3.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_File.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_G_S_C_Bike_Ride_Theme_(50_Times).mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_G_S_C_Goldenrod_City_Piano_Cover_Play_2_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Laura_Shigihara_-_Plants_Vs_Zombies_-_Watery_Grave_Piano.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_2.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_X2.mid
# Loading Music File: /content/path_to_directory/Midi/dragon_quest_4_-_Level_Up.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_X4.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_-_Neo_Green_Hill_Zone_Act_1_-_ (3).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Xenogears.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_BanjoB_Hill.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Conker's_bad_fur_day_Windy_Hill.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Poke_Center_(Piano_Ver.).mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Fire_Red_Pallet_Town_Theme_(50_Times).mid
# Loading Music File: /content/path_to_directory/Midi/Toby_Fox_-_Undertale_-_Waltzovania_-_Piano.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Sim_City.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Liquid_Crystal_Route_100_Theme_2_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_X.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_G_S_C_Goldenrod_City_Piano_Cover_50_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Cameron_Lee_Simpson_-_Mac_Dad_Z.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Sim_City_2000 (1).mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_Gourmet_Race_Round_1_and_3_(5_Times).mid
# Loading Music File: /content/path_to_directory/Midi/Animenz_-_This_Game_OP_Animenz_In_Eb.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Liquid_Crystal_Route_100_Theme_50_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_F-Zero.mid
# Loading Music File: /content/path_to_directory/Midi/Junichi_Masuda_-_Pokemon_DPPt_-_Route_201_-_Piano_Arranged_In_3_4_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Theme_Guitar_Cover_2_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Super_Mario_Kart.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Parappa_The_Rapper._Level_2.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Dragon's_Fury.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Tekken_2 (1).mid
# Loading Music File: /content/path_to_directory/Midi/Toby_Fox_-_Undertale_-_Waterfall_-_Piano_Arranged.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Sim_City_2000.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(2).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Mario_Kart_64.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Castlevania_4.mid
# Loading Music File: /content/path_to_directory/Midi/ZUN_-_The_Rabbit_Has_Landed.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Star_Fox_64.mid
# Loading Music File: /content/path_to_directory/Midi/ZUN_-_魔法決戦！～Fight_it_out!.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Tekken_2.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_X4 (1).mid
# Loading Music File: /content/path_to_directory/Midi/mario474__-_mario_theme_rap.mid
# Loading Music File: /content/path_to_directory/Midi/Zengarang_-_The_Promise_Bios_Medley.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Ridge_Racer.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_Gourmet_Race_Round_2_(5_Times).mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_-_Angel_Island_Act_1.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Xenogears (1).mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Sega_Mega_CD_BIOS.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_-_Egg_Rocket_Act_1_(1).mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_-_Neo_Green_Hill_Zone_Act_1_-_ (1).mid
# Loading Music File: /content/path_to_directory/Midi/Animenz_-_This_game_by_Animez_in_C_piano.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Pokemon_Snap.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Secret_Of_Mana.mid
# Loading Music File: /content/path_to_directory/Midi/Undertale_-_Megalovania (1).mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Donkey_Kong_64_DK_Island.mid
# Loading Music File: /content/path_to_directory/Midi/Animenz_-_This_game_By_Animenz.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_Opening_.mid
# Loading Music File: /content/path_to_directory/Midi/Aaron_Colin_Adams_-_Sonic_1-Mystery_Caves_Zone.mid
# Loading Music File: /content/path_to_directory/Midi/Konomi_Suzuki_-_This_game_(In_E_flat_Hard_version)(re-Modify).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_NHL_96.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_7_Peppermint_Palace_Play_2_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Route_1_Theme_Advanced_Version_(Play_3_Times).mid
# Loading Music File: /content/path_to_directory/Midi/PS1_PARASITE_EVE_-_HISTORY_MUSEUM_PE.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Fure_Red_Route_1_Play_3_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Leaf_Forest_Act_2.mid
# Loading Music File: /content/path_to_directory/Midi/The_Living_Tombstone_-_fnaf_its__be_so_long.mid
# Loading Music File: /content/path_to_directory/Midi/Junichi_Masuda_-_Pokemon_ORAS_-_Ending_-_Hard_Version.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_7_Peppermint_Palace_Play_50_Times.mid
# Loading Music File: /content/path_to_directory/Midi/ff_-_FFXII.mid
# Loading Music File: /content/path_to_directory/Midi/TheoAllen_-_Alkarian's_World.mid
# Loading Music File: /content/path_to_directory/Midi/Undertale_-_Determination.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Cool_Spot.mid
# Loading Music File: /content/path_to_directory/Midi/The_Living_Tombstone_-_fnaf_its__be_so_long (1).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Desert_Strike.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Duke_Nukem.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_-_Ice_Mountain_Act_1.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_GSC_Goldenrod_City_Violin_Cover_Play_50_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Nobuo_Uematsu_-_Final_Fantasy_VII_Main_Theme.mid
# Loading Music File: /content/path_to_directory/Midi/Animenz_-_This_game_op_by_Animenz_in_Eb_(Modify).mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_Gourmet_Race_Round_1_and_3_(20Times).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Super_Mario_World.mid
# Loading Music File: /content/path_to_directory/Midi/TheoAllen_-_Doomsday.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_1_RainBow_Route_Piano_Cover_Play_50_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(3).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Ridge_Racer (1).mid
# Loading Music File: /content/path_to_directory/Midi/Animez__-_This_Game_(In_E_flat_Advanced_Version)(re-modify).mid
# Loading Music File: /content/path_to_directory/Midi/Undertale_-_Sans.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(4).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_California_Games.mid
# Loading Music File: /content/path_to_directory/Midi/Junichi_Masuda_-_Pokemon_Fire_Red_-_Battle_Gym_Leader_-_Piano_Duet_-_Extended.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_2.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Theme_Overdriven_Guitar_Cover_50_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_-_Neo_Green_Hill_Zone_Act_1_-_.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_8.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_9_Candy_Constellation_Play_2_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Batman_Returns.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_and_The_Amazing_Mirror_Area_9_Candy_Constellation_Play_50_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Route_1_Theme_Advanced_Version.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Doom_64.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_3_mountain_.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Sonic_The_Hedgehog.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(5).mid
# Loading Music File: /content/path_to_directory/Midi/Lighthouse64_-_Green_Greens_(Kirby_Nightmare_in_Dreamland).mid
# Loading Music File: /content/path_to_directory/Midi/Arata_Iiyoshi_-_Primal_Dialga_Battle.mid
# Loading Music File: /content/path_to_directory/Midi/Animenz_-_This_game_OP_Animenz_In_C.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Final_Fantasy_8 (1).mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Kirby_Nightmare_In_Dreamland_Kirby_Air_Grind_Play_3_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Killer_Instinct.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_-_Angel_Island_Act_2.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Super_Mario_World_2__Yoshi's_Island.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Evening_Star_32x.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Bomberman_64.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_X3.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Goldeneye_007.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_G_S_C_Bike_Ride_Theme_(3_Times).mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pkmn-GSC-Route-1-Theme-Music-Box-2-Times.mid
# Loading Music File: /content/path_to_directory/Midi/Ben_Ridge_-_Clepton.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Illusion_Of_Gaia (1).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Zelda_3__A_Link_To_The_Past.mid
# Loading Music File: /content/path_to_directory/Midi/ENIX_-_Dragon_Warrior_3_(_Overworld_BGM_).mid
# Loading Music File: /content/path_to_directory/Midi/Undertale_-_Megalovania.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Zelda__Ocarina_Of_Time.mid
# Loading Music File: /content/path_to_directory/Midi/Undertale_-_Spear_Of_Justice.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Duke_Nukem (1).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Crash_Bandicoot_Warped.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Fire_Red_Route_1_Piano_Cover_Hard_Version.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Windows_Startup_.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_GSC_Goldenrod_City_Violin_Cover_Play_2_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Power_Rangers.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_-_Neo_Green_Hill_Zone_Act_1_-_ (2).mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_FRLG_Battle_Gym_Leader_Theme_Overdriven_Guitar_Cover_2_Times.mid
# Loading Music File: /content/path_to_directory/Midi/Sonic_Advance_2_-_Hot_Crater_Act_1_(1).mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Diddy_Kong.mid
# Loading Music File: /content/path_to_directory/Midi/Terranigma_-_Terranigma_-_Underworld.mid
# Loading Music File: /content/path_to_directory/Midi/Benjy_shelton__-_Banjo_Kazooie_Clanker's_Cavern.mid
# Loading Music File: /content/path_to_directory/Midi/Toby_Fox_-_Undertale_-_Bergentruckung_and_Asgore_-_Piano_-_Hard_Version.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Illusion_Of_Gaia.mid
# Loading Music File: /content/path_to_directory/Midi/Video_Game_Themes_-_Mega_Man_8.mid
# Loading Music File: /content/path_to_directory/Midi/Nintendo_-_Pokemon_Fire_Red_Version_Gym_Theme_(Piano_Ver.).mid
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#converting 2D array into 1D array
notes_ = [element for note_ in notes_array for element in note_]

#No. of unique notes
unique_notes = list(set(notes_))
print(len(unique_notes))
# Out:
# 375

# %%
#importing library
from collections import Counter

#computing frequency of each note
freq = dict(Counter(notes_))

#library for visualiation
import matplotlib.pyplot as plt

#consider only the frequencies
no=[count for _,count in freq.items()]

#set the figure size
plt.figure(figsize=(5,5))

#plot
plt.hist(no)

frequent_notes = [note_ for note_, count in freq.items() if count>=50]
print(len(frequent_notes))
# Out:
# 200

# %%
new_music=[]

for notes in notes_array:
    temp=[]
    for note_ in notes:
        if note_ in frequent_notes:
            temp.append(note_)            
    new_music.append(temp)
    
new_music = np.array(new_music)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   # This is added back by InteractiveShellApp.init_path()

# %%
no_of_timesteps = 32
x = []
y = []

for note_ in new_music:
    for i in range(0, len(note_) - no_of_timesteps, 1):
        
        #preparing input and output sequences
        input_ = note_[i:i + no_of_timesteps]
        output = note_[i + no_of_timesteps]
        
        x.append(input_)
        y.append(output)
        
x=np.array(x)
y=np.array(y)

# %%
unique_x = list(set(x.ravel()))
x_note_to_int = dict((note_, number) for number, note_ in enumerate(unique_x))

# %%
#preparing input sequences
x_seq=[]
for i in x:
    temp=[]
    for j in i:
        #assigning unique integer to every note
        temp.append(x_note_to_int[j])
    x_seq.append(temp)
    
x_seq = np.array(x_seq)

# %%
unique_y = list(set(y))
y_note_to_int = dict((note_, number) for number, note_ in enumerate(unique_y)) 
y_seq=np.array([y_note_to_int[i] for i in y])

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(x_seq,y_seq,test_size=0.2,random_state=0)

# %%
def lstm():
  model = Sequential()
  model.add(LSTM(128,return_sequences=True))
  model.add(LSTM(128))
  model.add(Dense(256))
  model.add(Activation('relu'))
  model.add(Dense(n_vocab))
  model.add(Activation('softmax'))
  model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')
  return model

# %%
K.clear_session()
model = Sequential()
    
#embedding layer
model.add(Embedding(len(unique_x), 100, input_length=32,trainable=True)) 

model.add(Conv1D(64,3, padding='causal',activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))
    
model.add(Conv1D(128,3,activation='relu',dilation_rate=2,padding='causal'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))

model.add(Conv1D(256,3,activation='relu',dilation_rate=4,padding='causal'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))
          
#model.add(Conv1D(256,5,activation='relu'))    
model.add(GlobalMaxPool1D())
    
model.add(Dense(256, activation='relu'))
model.add(Dense(len(unique_y), activation='softmax'))
    
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 32, 100)           20000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 32, 64)            19264
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 64)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 16, 64)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 16, 128)           24704
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 8, 128)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 8, 256)            98560
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 256)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 4, 256)            0
# _________________________________________________________________
# global_max_pooling1d (Global (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               65792
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               51400
# =================================================================
# Total params: 279,720
# Trainable params: 279,720
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc=ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True,verbose=1)
history = model.fit(np.array(x_tr),np.array(y_tr),batch_size=128,epochs=50, validation_data=(np.array(x_val),np.array(y_val)),verbose=1, callbacks=[mc])
model = load_model('best_model.h5')
# Out:
# Epoch 1/50
# 2814/2814 [==============================] - 66s 8ms/step - loss: 3.3672 - val_loss: 1.7978
#
# Epoch 00001: val_loss improved from inf to 1.79777, saving model to best_model.h5
# Epoch 2/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.7860 - val_loss: 1.0657
#
# Epoch 00002: val_loss improved from 1.79777 to 1.06575, saving model to best_model.h5
# Epoch 3/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.3469 - val_loss: 0.8094
#
# Epoch 00003: val_loss improved from 1.06575 to 0.80936, saving model to best_model.h5
# Epoch 4/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.1547 - val_loss: 0.6863
#
# Epoch 00004: val_loss improved from 0.80936 to 0.68631, saving model to best_model.h5
# Epoch 5/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.0490 - val_loss: 0.6253
#
# Epoch 00005: val_loss improved from 0.68631 to 0.62526, saving model to best_model.h5
# Epoch 6/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9804 - val_loss: 0.5827
#
# Epoch 00006: val_loss improved from 0.62526 to 0.58268, saving model to best_model.h5
# Epoch 7/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9261 - val_loss: 0.5544
#
# Epoch 00007: val_loss improved from 0.58268 to 0.55438, saving model to best_model.h5
# Epoch 8/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.8866 - val_loss: 0.5381
#
# Epoch 00008: val_loss improved from 0.55438 to 0.53807, saving model to best_model.h5
# Epoch 9/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.8570 - val_loss: 0.5273
#
# Epoch 00009: val_loss improved from 0.53807 to 0.52727, saving model to best_model.h5
# Epoch 10/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.8331 - val_loss: 0.5067
#
# Epoch 00010: val_loss improved from 0.52727 to 0.50670, saving model to best_model.h5
# Epoch 11/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.8116 - val_loss: 0.5044
#
# Epoch 00011: val_loss improved from 0.50670 to 0.50436, saving model to best_model.h5
# Epoch 12/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7994 - val_loss: 0.5000
#
# Epoch 00012: val_loss improved from 0.50436 to 0.49996, saving model to best_model.h5
# Epoch 13/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7843 - val_loss: 0.4826
#
# Epoch 00013: val_loss improved from 0.49996 to 0.48257, saving model to best_model.h5
# Epoch 14/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7724 - val_loss: 0.4748
#
# Epoch 00014: val_loss improved from 0.48257 to 0.47481, saving model to best_model.h5
# Epoch 15/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7575 - val_loss: 0.4785
#
# Epoch 00015: val_loss did not improve from 0.47481
# Epoch 16/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7498 - val_loss: 0.4801
#
# Epoch 00016: val_loss did not improve from 0.47481
# Epoch 17/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7427 - val_loss: 0.4757
#
# Epoch 00017: val_loss did not improve from 0.47481
# Epoch 18/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7329 - val_loss: 0.4692
#
# Epoch 00018: val_loss improved from 0.47481 to 0.46915, saving model to best_model.h5
# Epoch 19/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7247 - val_loss: 0.4654
#
# Epoch 00019: val_loss improved from 0.46915 to 0.46542, saving model to best_model.h5
# Epoch 20/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7201 - val_loss: 0.4622
#
# Epoch 00020: val_loss improved from 0.46542 to 0.46218, saving model to best_model.h5
# Epoch 21/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7123 - val_loss: 0.4677
#
# Epoch 00021: val_loss did not improve from 0.46218
# Epoch 22/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7146 - val_loss: 0.4564
#
# Epoch 00022: val_loss improved from 0.46218 to 0.45636, saving model to best_model.h5
# Epoch 23/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7060 - val_loss: 0.4515
#
# Epoch 00023: val_loss improved from 0.45636 to 0.45148, saving model to best_model.h5
# Epoch 24/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.7054 - val_loss: 0.4577
#
# Epoch 00024: val_loss did not improve from 0.45148
# Epoch 25/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6991 - val_loss: 0.4494
#
# Epoch 00025: val_loss improved from 0.45148 to 0.44944, saving model to best_model.h5
# Epoch 26/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6933 - val_loss: 0.4492
#
# Epoch 00026: val_loss improved from 0.44944 to 0.44919, saving model to best_model.h5
# Epoch 27/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6898 - val_loss: 0.4519
#
# Epoch 00027: val_loss did not improve from 0.44919
# Epoch 28/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6849 - val_loss: 0.4461
#
# Epoch 00028: val_loss improved from 0.44919 to 0.44608, saving model to best_model.h5
# Epoch 29/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6782 - val_loss: 0.4550
#
# Epoch 00029: val_loss did not improve from 0.44608
# Epoch 30/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6799 - val_loss: 0.4510
#
# Epoch 00030: val_loss did not improve from 0.44608
# Epoch 31/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6757 - val_loss: 0.4456
#
# Epoch 00031: val_loss improved from 0.44608 to 0.44555, saving model to best_model.h5
# Epoch 32/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6722 - val_loss: 0.4460
#
# Epoch 00032: val_loss did not improve from 0.44555
# Epoch 33/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6680 - val_loss: 0.4470
#
# Epoch 00033: val_loss did not improve from 0.44555
# Epoch 34/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6675 - val_loss: 0.4468
#
# Epoch 00034: val_loss did not improve from 0.44555
# Epoch 35/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6696 - val_loss: 0.4435
#
# Epoch 00035: val_loss improved from 0.44555 to 0.44353, saving model to best_model.h5
# Epoch 36/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6651 - val_loss: 0.4413
#
# Epoch 00036: val_loss improved from 0.44353 to 0.44126, saving model to best_model.h5
# Epoch 37/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6644 - val_loss: 0.4400
#
# Epoch 00037: val_loss improved from 0.44126 to 0.43998, saving model to best_model.h5
# Epoch 38/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6642 - val_loss: 0.4366
#
# Epoch 00038: val_loss improved from 0.43998 to 0.43657, saving model to best_model.h5
# Epoch 39/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6596 - val_loss: 0.4434
#
# Epoch 00039: val_loss did not improve from 0.43657
# Epoch 40/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6536 - val_loss: 0.4400
#
# Epoch 00040: val_loss did not improve from 0.43657
# Epoch 41/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6515 - val_loss: 0.4431
#
# Epoch 00041: val_loss did not improve from 0.43657
# Epoch 42/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6498 - val_loss: 0.4410
#
# Epoch 00042: val_loss did not improve from 0.43657
# Epoch 43/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6533 - val_loss: 0.4426
#
# Epoch 00043: val_loss did not improve from 0.43657
# Epoch 44/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6493 - val_loss: 0.4388
#
# Epoch 00044: val_loss did not improve from 0.43657
# Epoch 45/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6434 - val_loss: 0.4375
#
# Epoch 00045: val_loss did not improve from 0.43657
# Epoch 46/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6416 - val_loss: 0.4342
#
# Epoch 00046: val_loss improved from 0.43657 to 0.43417, saving model to best_model.h5
# Epoch 47/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6460 - val_loss: 0.4386
#
# Epoch 00047: val_loss did not improve from 0.43417
# Epoch 48/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6494 - val_loss: 0.4380
#
# Epoch 00048: val_loss did not improve from 0.43417
# Epoch 49/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6384 - val_loss: 0.4381
#
# Epoch 00049: val_loss did not improve from 0.43417
# Epoch 50/50
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.6408 - val_loss: 0.4313
#
# Epoch 00050: val_loss improved from 0.43417 to 0.43126, saving model to best_model.h5

# %%
ind = np.random.randint(0,len(x_val)-1)

random_music = x_val[ind]

predictions=[]
for i in range(10):

    random_music = random_music.reshape(1,no_of_timesteps)

    prob  = model.predict(random_music)[0]
    y_pred= np.argmax(prob,axis=0)
    predictions.append(y_pred)

    random_music = np.insert(random_music[0],len(random_music[0]),y_pred)
    random_music = random_music[1:]
    
print(predictions)
# Out:
# [171, 171, 23, 23, 23, 171, 132, 23, 22, 42]

# %%
x_int_to_note = dict((number, note_) for number, note_ in enumerate(unique_x)) 
predicted_notes = [x_int_to_note[i] for i in predictions]

# %%
def convert_to_midi(prediction_output):
   
    offset = 0
    output_notes = []

    # create note and chord objects based on the values generated by the model
    for pattern in prediction_output:
        
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                
                cn=int(current_note)
                new_note = note.Note(cn)
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
                
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
            
        # pattern is a note
        else:
            
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)

        # increase offset each iteration so that notes do not stack
        offset += 1
    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp='music.mid')

# %%
convert_to_midi(predicted_notes)
